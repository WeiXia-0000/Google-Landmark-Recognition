# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

def download_train():
  datadir = "/content/drive/MyDrive/data/project/data/train"
  if not os.path.exists(datadir):
    # !ln -s "/content/drive/MyDrive/data/project/data/train" $datadir
  os.chdir(datadir)
  # !pwd
  # Executes bash script
  # !bash /content/drive/MyDrive/data/project/data/download-dataset.sh train 499

def download_test():
  datadir = "/content/drive/MyDrive/cs444-final-project/project/data/test"
  if not os.path.exists(datadir):
    # !ln -s "/content/drive/MyDrive/cs444-final-project/project/data/test" $datadir
  os.chdir(datadir)
  # !pwd
  # !bash /content/drive/MyDrive/cs444-final-project/project/data/download-dataset.sh test 19

# %%
download_train()
# Out:
# /content/drive/.shortcut-targets-by-id/1ZYllns3KF8jlDBSw-tTypG2SgvefF2s2/project/data/train
# ...
